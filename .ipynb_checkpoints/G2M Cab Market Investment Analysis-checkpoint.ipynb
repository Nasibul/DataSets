# %% [markdown]
# ## Primary Imports

# %%
import numpy as np
import pandas as pd
import statistics
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Data

# %%
cab_data=pd.read_csv("Cab_Data.csv")
city=pd.read_csv("City.csv")
customer_id=pd.read_csv("Customer_ID.csv")
transaction_id=pd.read_csv("Transaction_ID.csv")

# %% [markdown]
# ## Preliminary Data Cleaning and Exploration

# %%
def data_explore(df):
    display(df.info())
    display(df.describe())
    print('\n')
    print("First 5 rows")
    display(df.head(5))

# %%
data_explore(cab_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB
# None
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000
# First 5 rows
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
data_explore(city)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
# None
#              City   Population     Users
# count          20           20        20
# unique         20           20        20
# top     DALLAS TX   1,339,155    22,157
# freq            1            1         1
# First 5 rows
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
data_explore(customer_id)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000
# First 5 rows
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
data_explore(transaction_id)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB
# None
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000
# First 5 rows
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %% [markdown]
# It seems that cab_data is the one that deserves the most focus considering it records the details of every single ride. However, the "Date of Travel" column shows sequential integers. The time period that this dataset is meant to cover is from 1/1/2016 to 12/31/2018. This column needs to be reformatted into datetime objects in order to display the proper dates and be utilized for further analysis. Considering the very first date starts off as 42371, I will subtract all the dates by that number and then repopulate the dates column with the proper range of dates, starting from 01/31/2016.

# %%
cab_data=cab_data.sort_values(by=["Date of Travel"])
cab_data["Date of Travel"]=cab_data["Date of Travel"]-42371
from datetime import date, timedelta
start_date=date(2016,1,1)
def dates(x):
    true_date=start_date+timedelta(days=x)
    return true_date

cab_data["Date of Travel"]=cab_data["Date of Travel"].apply(dates)
cab_data["Date of Travel"]=pd.to_datetime(cab_data["Date of Travel"])
cab_data["Weekday"]=cab_data["Date of Travel"].dt.day_name()

# %% [markdown]
# Additonal features will have to be added for the sake of analysis and analyzing categories.

# %%
cab_data["Profit"]=cab_data["Price Charged"]-cab_data["Cost of Trip"]
customer_id["Income (USD/Year)"]=customer_id["Income (USD/Month)"]*12
customer_id["Age Category"]=pd.cut(customer_id["Age"],\
                                 bins=[18,30,45,65],\
                                 labels=["18-30","31-45","46-65"])
customer_id["Income Bracket"]=pd.cut(customer_id["Income (USD/Year)"],\
                                 bins=[0,52200,156600,1000000],\
                                 labels=["Low income","Middle income","Upper income"])

# %% [markdown]
# ## Research Questions

# %% [markdown]
# The ultimate goal of this analysis is to figure out which company to invest in. There are many areas to investigate.

# %%
color=['pink','yellow']

# %% [markdown]
# ### Seasonality Across Years

# %%
seasonality=cab_data.groupby(by="Company")\
            .resample("M",on="Date of Travel")\
            .size()\
            .T\
            .plot(figsize=(15,10),color=color)

# %% [markdown]
# Based on this graph, both companies suffer from the same dips around the beginning of the year and peaks near the holiday time at the end of the year. However, the number of rides of the Yellow Cab company completely dwarf that of the Pink Cab company.

# %% [markdown]
# ### Distribution of Customers by Age

# %%
main_table=cab_data.merge(transaction_id,on="Transaction ID",how="inner")\
            .merge(customer_id,on="Customer ID",how="inner")

# %% [markdown]
# A few tables have to be joined together in order to properly match customer age to customer ids to the actual rides in the the cab_data dataframe.

# %%
plt.subplot(1,2,1)
main_table[main_table["Company"]=="Yellow Cab"]\
.groupby(by="Age Category")\
.size()\
.plot(kind="pie",figsize=(15,15),label='',title="Yellow Cab",autopct="%1.1f%%")

plt.subplot(1,2,2)
main_table[main_table["Company"]=="Pink Cab"]\
.groupby(by="Age Category")\
.size()\
.plot(kind="pie",figsize=(15,15),label='',title="Pink Cab",autopct="%1.1f%%")
# Out:
# <AxesSubplot:title={'center':'Pink Cab'}>

# %% [markdown]
# It seems that both of these companies have similar age distributions and neither comes out as more favorable from this analysis.

# %% [markdown]
# ### Profits by Location

# %%
cab_data.groupby(by=["City","Company"])["Profit"]\
.sum()\
.plot(kind='barh',figsize=(15,12),color=color,xlim=[0,4000000],fontsize=10)
plt.title("Profit USD in Millions",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Profit USD in Millions')

# %% [markdown]
# It seems that the Yellow Cab company beats out the Pink Cab company in every single city. In some cities, it is by a bit while in others, the Yellow Cab company has multiple times the amount of profits as the Pink Cab company.

# %% [markdown]
# ### Customer Segmentation across Location, Income and Age

# %%
pink_segmentation=main_table[main_table["Company"]=="Pink Cab"].groupby(by=["City","Income Bracket","Age Category"])\
                                                               .size()
pink_segmentation.sort_values(ascending=False)[0:10]\
                 .plot(kind="barh",figsize=(15,10),fontsize=15)
plt.title("Top 10 Customer Segments for the Pink Cab Company",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Top 10 Customer Segments for the Pink Cab Company')

# %%
yellow_segmentation=main_table[main_table["Company"]=="Yellow Cab"].groupby(by=["City","Income Bracket","Age Category"])\
                                                                   .size()
yellow_segmentation.sort_values(ascending=False)[0:10]\
                 .plot(kind="barh",figsize=(15,10),fontsize=15)
plt.title("Top 10 Customer Segments for the Yellow Cab Company",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Top 10 Customer Segments for the Yellow Cab Company')

# %% [markdown]
# Wealthy individuals in LA from the ages of 18-30 are the biggest customer base for the Pink Cab company while wealthy middle aged individuals from New York City are the biggest customer base for the Yellow Cab Company.

# %% [markdown]
# ### Profits Across The Week

# %%
cab_data.groupby(by=["Weekday","Company"])["Profit"]\
        .sum()\
        .plot(kind='barh',figsize=(16,10),color=color,fontsize=15)
plt.title("Profit USD in Millions",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Profit USD in Millions')

# %% [markdown]
# Again, the Yellow Cab company consistently beats the Pink Cab company by many times the profit across various days. It seems that the most cabs are called on Thursdays, Fridays and Saturdays. A possible reason for this could be that people want to travel at the end of the work week.

# %% [markdown]
# ### Profits by Company

# %%
plt.subplots(1,2,sharey=True)

plt.subplot(1,2,1)
cab_data[cab_data["Company"]=="Yellow Cab"]["Profit"]\
.plot(kind="box",figsize=(15,10),label='',title="Yellow Cab",showfliers=False,grid=True)

plt.subplot(1,2,2)
cab_data[cab_data["Company"]=="Pink Cab"]["Profit"]\
.plot(kind="box",figsize=(15,10),label='',title="Pink Cab",showfliers=False,grid=True)
# Out:
# <AxesSubplot:title={'center':'Pink Cab'}>

# %% [markdown]
# These boxplots show just how much the distributions of the profits from each company differ. The median and max profit of the Pink Cab company is much lower than those of the Yellow Cab company.

# %%
cab_data.groupby(by=["Company"])["Profit"]\
        .describe()
# Out:
#                count        mean         std       min     25%    50%  \
# Company
# Pink Cab     84711.0   62.652174   77.590378 -220.0600  11.206   41.5
# Yellow Cab  274681.0  160.259986  171.823833 -176.9308  37.180  102.0
#
#                  75%       max
# Company
# Pink Cab     93.9650  1119.480
# Yellow Cab  228.6704  1463.966

# %%
cab_data.groupby(by=["Company"])["Profit"]\
.sum()\
.plot(kind='barh',figsize=(15,5),color=color)
plt.title("Total Profit USD in Millions",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Total Profit USD in Millions')

# %% [markdown]
# Overall, we can see that the Yellow Cab company has 10x the profit of the Pink Cab company.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# There is not a single analysis where Pink Cab has beaten Yellow Cab. In any direct comparison between companies, Yellow Cab dominates by a large margin.
